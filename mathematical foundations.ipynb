# %%
user=[5,2,8,4]#ratings

# %%
apple=[4,5,1]
banana=[2,3,0]

# %%
import numpy as np
a=np.array([3,7])
b=np.array([2,5])
print(a+b)
# Out:
# [ 5 12]

# %%
x=np.array([
  [2,4],
  [3,1],
  [4,7]
])

# %%
import numpy as np
scores=[44,58,82,23]
print(np.mean(scores))
# Out:
# 51.75

# %%
import random
outcomes=["spam","not spam"]
print(random.choice(outcomes))
# Out:
# spam

# %%
w=9
ir=0.2
for i in range(10):
  w=w-ir*2*w
  print(w)
# Out:
# 5.4
# 3.24
# 1.944
# 1.1663999999999999
# 0.6998399999999999
# 0.41990399999999994
# 0.25194239999999996
# 0.15116543999999998
# 0.09069926399999999
# 0.05441955839999999
