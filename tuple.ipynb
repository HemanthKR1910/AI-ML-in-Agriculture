# %%
student={
"name":"hemanth",
"age":22,
"course":"CSE"
}
print(student["course"])
# Out:
# CSE

# %%
marks={
 "maths":78,
 "science":87,
}
marks["english"]=88
print(marks)
# Out:
# {'maths': 78, 'science': 87, 'english': 88}
