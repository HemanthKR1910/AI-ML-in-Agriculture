# %%
rainfall = 1500
if rainfall > 750:
  print("rice is suitable")
else:
  print("wheat is suitable")
# Out:
# rice is suitable

# %%
income=80000
landavailability=3.5
if(income<100000 and landavailability<2.5):
 print("eligible for loan")
elif(income>=100000 and landavailability>=2.5):
 print("eligible for loan")
else:
  print("not eligible for loan")
# Out:
# not eligible for loan
