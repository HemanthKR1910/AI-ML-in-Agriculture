# %%
a=11
if(a>6):
  print("11 is greater than 6")
# Out:
# 11 is greater than 6

# %%
day="tuesday"
if ( day=="saturday"):
  print("colour dress")
else:
  print("uniform")
# Out:
# uniform

# %%
name="hemanth"
age=22
print(f"my name is {name}, and age is {age}")
# Out:
# my name is hemanth, and age is 22
