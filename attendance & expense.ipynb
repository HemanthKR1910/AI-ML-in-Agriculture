# %%
file=open("attendance.txt",'w')
file.write("students name:\n hemanth p \n ravi p \n madhu a")
file.close()

# %%
file=open("attendance.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# students name:
#  hemanth p
#  ravi p
#  madhu a

# %%
file=open("attendance.txt","a")
file.write("ALL ARE PRESENT")
file.close()

# %%
file=open("attendance.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# students name:
#  hemanth p
#  ravi p
#  madhu a

# %%
file=open("expense.txt","w")
file.write("07.12.25 \n 300rs \n biriyani")
file.close()

# %%
file=open("expense.txt","w")
file.write("07.12.25 \n 300rs \n biriyani")
file.close()

# %%
import numpy as np
a=np.array([1,4,6])
b=np.array([3,2,7])
print(a+b)
# Out:
# [ 4  6 13]

# %%
np.dot([1,3],[2,3])
# Out:
# np.int64(11)

# %%
np.dot([2,5],[4,1])
# Out:
# np.int64(13)

# %%
import numpy as np
scores=[88,75,89]
print(np.mean(scores))
# Out:
# 84.0

# %%
w=7
ir=0.2
for i in range(5):
  w=w-ir*2*w
  print(w)
# Out:
# 4.199999999999999
# 2.5199999999999996
# 1.5119999999999998
# 0.9071999999999998
# 0.5443199999999999

# %%
x= np.array([
 [1,2],
 [2,3],
])
