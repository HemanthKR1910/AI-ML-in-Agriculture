# %%
soil_nitrogen=float(input("Enter the soil nitrogen level(mg/kg):"))
if soil_nitrogen < 100:
    recommendation="high fertilizer"
    cost=2000
elif 100 <= soil_nitrogen <= 250:
   recommendation="medium fertilizer"
   cost=1000
else:
   recommendation="no fertilizer is needed"
   cost=0
# Out:
# Enter the soil nitrogen level(mg/kg):250
