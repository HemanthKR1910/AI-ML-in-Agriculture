# %%
import numpy as np
scores=[24,15,36,45]
print(np.mean(scores))
# Out:
# 30.0

# %%
import numpy as np
cricketscores=[20,33,49,93]
print(np.median(cricketscores))
# Out:
# 41.0

# %%
import statistics as np
votes=[2,4,4,6,7,4,1,9]
print(np.mode(votes))
# Out:
# 4

# %%
import numpy as np
tigh_data=[30,50,70]
spread_data=[20,80,140]

print("tight std:", np.std(tigh_data))
print("spread std:", np.std(spread_data))
# Out:
# tight std: 16.32993161855452
# spread std: 48.98979485566356

# %%
import random
#simulating random predictions
for i in range(7):
  prediction=random.choice(["spam","not spam"])
  print(f"email{i+1}:{prediction}")
# Out:
# email1:not spam
# email2:spam
# email3:not spam
# email4:spam
# email5:not spam
# email6:not spam
# email7:spam

# %%
import random
#simulate 15 dice rolls
samples=[random.randint(2,7) for _ in range(15)]
print("sample rolls:",samples)
print("sample mean:",sum(samples)/len(samples))
# Out:
# sample rolls: [7, 7, 3, 3, 7, 4, 6, 2, 3, 2, 4, 4, 7, 7, 5]
# sample mean: 4.733333333333333
