# %%
text="hemanth"
print(text[0:5])
# Out:
# heman

# %%
name="manoj"
print(len(name))
# Out:
# 5

# %%
text=("raju mighty")
text=text.upper()
print(text)
# Out:
# RAJU MIGHTY

# %%
text=("chotta bheem")
text=text.title()
print(text)
# Out:
# Chotta Bheem

# %%
data="Hemanth K R"
print(data.strip())
# Out:
# Hemanth K R

# %%
msg="i like icecream"
print(msg.replace("icecream","biriyani"))
# Out:
# i like biriyani

# %%
email="krhemanth%gmail.in"
print("@" in email)
# Out:
# False

# %%
words=["GKVK","is","best"]
print("".join(words))
# Out:
# GKVKisbest

# %%
sentence="i like icecream"
words=sentence.split()
print(words)
# Out:
# ['i', 'like', 'icecream']

# %%
name="Hemanth"
age=22
print("my name is Hemanth and i'm 22 years old")
# Out:
# my name is Hemanth and i'm 22 years old

# %%
first="good"
second="afternoon"
print(first+""+second)
# Out:
# goodafternoon

# %%
text="mahabalipuram"
print(text.count("a"))
# Out:
# 4
