# %%
name="hemanth k r"
age=22
print("hello,", name)
print("you are", age, "years old")
# Out:
# hello, hemanth k r
# you are 22 years old

# %%
rows=int(input("enter number of rows"))
for i in range(1,rows+1):
  for j in range
# Out:
#   File "/tmp/ipython-input-3833303328.py", line 3
#     for j in range
#                   ^
# SyntaxError: expected ':'

# %%
x=5
y=2
z=x+y*3
print(z)
# Out:
# 11

# %%
a=10
b=a-3
a=a+1
print(a,b)
# Out:
# 11 7

# %%
mark1=59
mark2=88
mark3=75
total=mark1+mark2+mark3
average=total/3
print("total=",total)
print("average=",average)
# Out:
# total= 222
# average= 74.0

# %%
mark=int(input("entermark"))
if mark>=90:
  print("grade A")
elif mark>=75:
  print("grade B")
else:
  print("grade C")
# Out:
# entermark98
# grade A

# %%
age=int(input("enter age"))
if age<12 or age>60:
  print("discount granted")
else:
  print("discount not granted")
# Out:
# enter age56
# discount not granted

# %%
N=int(input("enter N:"))
total=0
for i in range(1,N+1):
 total=total+i
print("sum=",total)
# Out:
# enter N:78
# sum= 3081

# %%
marks=[56,78,90,45,88]

#max
max_mark=max(marks)

#average
total=0
for m in marks:
 total=total+m
average=total/len(marks)

#count>=60
count=0
for m in marks:
  if m>=60:
   count=count+1

print("max:",max_mark)
print("average:",average)
print("count>=60:",count)
# Out:
# max: 90
# average: 71.4
# count>=60: 3

# %%
count=0
for n in marks:
  if n>0:
   count=count+1
print("positive numbers count:",count)
# Out:
# positive numbers count: 5

# %%
def average_marks(marks_list):
  total=0
  for m in marks_list:
    total=total+m
  avg=total/len(marks_list)
  return avg

# %%
rows=int(input("enter number of rows"))
for i in range(1,rows+1):
  print("*"*i)
# Out:
# enter number of rows8
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********

# %%
a=10
b=5
c=a+b
print(c)
# Out:
# 15

# %%
numbers=[10,-3,5,0,8,-2]
count=0
for num in numbers:
 if num>0:
  count+=1
print("positive count(loop):",count)
# Out:
# positive count(loop): 3
